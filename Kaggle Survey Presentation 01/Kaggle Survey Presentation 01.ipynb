# %% [markdown]
# ## All technology savvy people very conversant with Machine learning word  is it a myth ? Kaggle community really gave this interesting  opportunity to look into all cross sections of world are becoming aware Machine Learning or not ?
#
# ### Only technology savvy people are much very conversant with Machine learning word,  is it a myth ? Kaggle community really gave this interesting opportunity to look into all cross sections of world are becoming aware Machine Learning/Data science or not ?
#
# ### Here we done research to find world economy & governments also focusing on technology advancement  , please see following information . It proves there is urge , hence top down approach will make impact on all socio economic groups.
#
# ### Government enforcing AI strategies to  move forward WW economy –

# %% [markdown]
# ![image.png](attachment:image.png)
#                                                                    Government enforcing  AI strategies to step up –source(-https://medium.com/politics-ai)

# %% [markdown]
# ## Our survey data  can depict  trend /association with economy (?) and all are getting attracted towards ML , hence we are classifying data on income groups as first variable to check hypothesis. We already know universities and students are moving in this direction from various secondary sources.

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) 
# will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['SurveySchema.csv', 'freeFormResponses.csv', 'multipleChoiceResponses.csv']

# %%
import matplotlib.pyplot as plt

# %%
df1 = pd.read_csv('../input/multipleChoiceResponses.csv')
df1.dataframeName = 'multipleChoice.csv'
nRow, nCol = df1.shape
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,2,8,10,21,23,24,25,26,27,28,44,56,64,83,85,87,107,109,123,125,150,157,172,174,194,210,218,219,223,246,249,262,264,276,277,278,279,280,281,282,283,284,285,286,287,288,289,290,304,306,325,326,329,341,368,371,384,385,389,390,391,393,394) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df1.shape
# Out:
# (23860, 395)

# %%
# Incomedf01 = Incomedf01[Incomedf01['Q9_Mean'] != 'null']
df1 = df1[df1['Q1'] !='What is your gender? - Selected Choice']

# %%
df1.shape
# Out:
# (23859, 395)

# %%
# df1['Q9_Mean'].replace('70-80,000',75000,inplace=True)
Incomedf01 = df1.copy(deep = True)

# %%
Incomedf01['Q9_Mean'] = Incomedf01['Q9']

# %%
Incomedf01['Q9_Mean'].replace('0-10,000',5000,inplace=True)
Incomedf01['Q9_Mean'].replace('10-20,000',15000,inplace=True)
Incomedf01['Q9_Mean'].replace('20-30,000',25000,inplace=True)
Incomedf01['Q9_Mean'].replace('30-40,000',35000,inplace=True)
Incomedf01['Q9_Mean'].replace('40-50,000',45000,inplace=True)
Incomedf01['Q9_Mean'].replace('50-60,000',55000,inplace=True)
Incomedf01['Q9_Mean'].replace('60-70,000',65000,inplace=True)
Incomedf01['Q9_Mean'].replace('70-80,000',75000,inplace=True)
Incomedf01['Q9_Mean'].replace('80-90,000',85000,inplace=True)
Incomedf01['Q9_Mean'].replace('90-100,000',95000,inplace=True)
Incomedf01['Q9_Mean'].replace('100-125,000',112500,inplace=True)
Incomedf01['Q9_Mean'].replace('125-150,000',137500,inplace=True)
Incomedf01['Q9_Mean'].replace('150-200,000',175000,inplace=True)
Incomedf01['Q9_Mean'].replace('200-250,000',225000,inplace=True)
Incomedf01['Q9_Mean'].replace('250-300,000',275000,inplace=True)
Incomedf01['Q9_Mean'].replace('300-400,000',350000,inplace=True)
Incomedf01['Q9_Mean'].replace('400-500,000',450000,inplace=True)
Incomedf01['Q9_Mean'].replace('500,000+',550000,inplace=True)

# %%
Incomedf01 = Incomedf01[pd.notnull(Incomedf01['Q9'])]

# %%
Incomedf01.shape
# Out:
# (20185, 396)

# %%
Incomedf01['Q9_Mean'].value_counts()
# Out:
# I do not wish to disclose my approximate yearly compensation    4756
# 5000                                                            4398
# 15000                                                           1937
# 25000                                                           1395
# 35000                                                           1119
# 45000                                                            965
# 55000                                                            919
# 112500                                                           843
# 65000                                                            729
# 75000                                                            677
# 95000                                                            566
# 137500                                                           533
# 85000                                                            506
# 175000                                                           457
# ...

# %%
Incomedf01['Q9'].replace('I do not wish to disclose my approximate yearly compensation','null',inplace=True)

# %%
Incomedf01 = Incomedf01[Incomedf01['Q9'] != 'null']

# %%
Incomedf01.shape
# Out:
# (15429, 396)

# %% [markdown]
# ## Out of 23859 respondents , 15429 declared their income in given categories. We determined class marks of groups and then found mean income of all different groups/ segments of survey respondents. Distribution of respondents (Income / no income)

# %% [markdown]
# ## We are using only data of respondents who depicted their income in story 1 ,
# ## For students we will have story 2.
# ## So our new database  comprises 15429 survey respondents.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. Gender Wise

# %% [markdown]
# # Income difference always surfaces issue of  gender inequality and our data also claims the same.
# ![image.png](attachment:image.png)

# %% [markdown]
# # 	Average income shows   51,354 of males and for females it is 44,799, yearly compensation. We may look into deeper data regarding  number of years of experience and also education level relation  with income in later tabulations / statistics.

# %% [markdown]
# # 2. Age Wise

# %%
Incomedf01['Q9_Mean'].value_counts()
# Out:
# 5000      4398
# 15000     1937
# 25000     1395
# 35000     1119
# 45000      965
# 55000      919
# 112500     843
# 65000      729
# 75000      677
# 95000      566
# 137500     533
# 85000      506
# 175000     457
# 225000     172
# 275000      75
# 550000      63
# 350000      52
# 450000      23
# Name: Q9_Mean, dtype: int64

# %%
AgeGroup = Incomedf01.groupby('Q2')
print (AgeGroup['Q9_Mean'].agg(np.size))
# Out:
# Q2
# 18-21    1363
# 22-24    2894
# 25-29    4278
# 30-34    2819
# 35-39    1637
# 40-44     989
# 45-49     602
# 50-54     403
# 55-59     222
# 60-69     180
# 70-79      26
# 80+        16
# Name: Q9_Mean, dtype: int64

# %%
Incomedf01['Q9_Mean']=Incomedf01['Q9_Mean'].astype(int)

# %%
print (AgeGroup['Q9_Mean'].agg([np.sum, np.mean,np.size]))
# Out:
#              sum           mean  size
# Q2
# 18-21   17695000   12982.391783  1363
# 22-24   67995000   23495.162405  2894
# 25-29  175982500   41136.629266  4278
# 30-34  172192500   61082.830791  2819
# 35-39  120677500   73718.692731  1637
# 40-44   76072500   76918.604651   989
# 45-49   56455000   93779.069767   602
# 50-54   42005000  104230.769231   403
# 55-59   26587500  119763.513514   222
# 60-69   21640000  120222.222222   180
# 70-79    2597500   99903.846154    26
# 80+      4720000  295000.000000    16

# %% [markdown]
# ## Python matplotlib for showing respondents age and  mean income trend (above sixty people with high income participated in this survey) .
# ## Age wise increasing trend of average income, statistical correlation shown , but for  above 70 some more analysis to be done as numbers are less those may be pulling average towards outlier figure. In story 2 we will analyze senior citizens group (>59 years)in more details.

# %%
xx=AgeGroup['Q9_Mean'].agg(np.mean)
a1=xx.sort_values(ascending=True)
xticklabels=a1.index
fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.set_xticklabels(xticklabels, rotation = 45)
plt.plot(a1)

# %% [markdown]
# ## 	Age group and mean  income analyzed and tabulated , for age group more than 60 there are less respondents hence those are not taken in this analysis. There is some interesting observations people with older age also have good average income , very high social income groups & elderly people are also responding , aware on ML which is shows penetration level is increasing.
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Education Wise

# %%
EduGroup = Incomedf01.groupby('Q4')
print (EduGroup['Q9_Mean'].agg(np.mean))
# Out:
# Q4
# Bachelor’s degree                                                    40185.375314
# Doctoral degree                                                      67175.852498
# I prefer not to answer                                               54576.923077
# Master’s degree                                                      52464.315125
# No formal education past high school                                 68555.555556
# Professional degree                                                  43697.916667
# Some college/university study without earning a bachelor’s degree    40212.224109
# Name: Q9_Mean, dtype: float64

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
fig_size[1] = 9

yy=EduGroup['Q9_Mean'].agg(np.mean)
b1=yy.sort_values(ascending=True)
xticklabels=b1.index
fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.set_xticklabels(xticklabels, rotation = 45)
plt.plot(b1)

# %% [markdown]
# ## There is correlation between formal education and income ( here we are excluding people who have not answered or said no school/formal education)
# ## Here we are showing histogram  and line graph for correlation , as formal education grows mean income also grows.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Here education level we are converting to number  of years to get correlation coefficient.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. Role / Occupation  Wise

# %%
RoleGroup = Incomedf01.groupby('Q6')
print (RoleGroup['Q9_Mean'].agg(np.mean))
# Out:
# Q6
# Business Analyst            48016.949153
# Chief Officer              132470.119522
# Consultant                  72181.500873
# DBA/Database Engineer       47478.632479
# Data Analyst                42373.949580
# Data Engineer               56254.432624
# Data Journalist             73250.000000
# Data Scientist              65960.295476
# Developer Advocate          46735.294118
# Manager                     93667.035398
# Marketing Analyst           49396.551724
# Other                       59001.472031
# Principal Investigator     107710.843373
# Product/Project Manager     70805.471125
# Research Assistant          24619.686801
# Research Scientist          54894.594595
# Salesperson                 58031.250000
# Software Engineer           50194.444444
# Statistician                54236.111111
# Student                     12306.297710
# Name: Q9_Mean, dtype: float64

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
fig_size[1] = 9

zz=RoleGroup['Q9_Mean'].agg(np.mean)
c1=zz.sort_values(ascending=True)
xticklabels=c1.index
fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.set_xticklabels(xticklabels, rotation = 45)
plt.plot(c1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## As per occupation/current role what is position of data scientist on mean income , it can be one of good finding of this survey.
# ## Students income ranging from 12000 per annum and high income of managers , principal investigaros/chief officers till more than 1,20000 . Data scientist at average income more than 60000.

# %% [markdown]
# # 5. Machine Learning Tool

# %%
MLGroup = Incomedf01.groupby('Q10')
print (MLGroup['Q9_Mean'].agg(np.mean))
# Out:
# Q10
# I do not know                                                                                25543.948127
# No (we do not use ML methods)                                                                35124.076809
# We are exploring ML methods (and may one day put a model into production)                    48546.897547
# We have well established ML methods (i.e., models in production for more than 2 years)       83007.760532
# We recently started using ML methods (i.e., models in production for less than 2 years)      56808.882236
# We use ML methods for generating insights (but do not put working models into production)    57889.194139
# Name: Q9_Mean, dtype: float64

# %%
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 15
fig_size[1] = 9

xyz=MLGroup['Q9_Mean'].agg(np.mean)
d1=xyz.sort_values(ascending=True)
xticklabels=d1.index
fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.set_xticklabels(xticklabels, rotation = 45)
plt.plot(d1)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Here we need more validation of data in next version of analysis  whether really respondents who are incorporating ML are having greater income, we need to prove statistically this  hypothesis .
# ## But trend shows slightly higher income of respondents who have current employment where employers are using or incorporating ML .

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 6. Country & Economy- Average income of respondents by country

# %% [markdown]
# ## Group of  respondents (who mentioned income)  from 58 countries participated & average income shown, where USA at 2nd position and India at 44th rank .
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Hence we tried to analysis data using mean income groups and other data variables. in next story we will do more in-depth analysis related to all Demographic information.
#
# ## We Enthusiastic Participants
#
# ## 1. Dr. Anuprita Deshmukh
# ## 2. Ms. Gauri Gavate
# ## 3. Mr. Ajay Dhanwat
